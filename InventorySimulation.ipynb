# %%
from inventory_simulation import simulation_functions as sf

# %% [markdown]
# # Simpy Inventory Simulation with multiple risks

# %% [markdown]
# In this run multiple risks are applied. You can see that quite often the safety stock is needed.

# %% [markdown]
# # Policy Safety Stock
# Order as soon as intentory is below safety stock (kind of stupid...)

# %%
cost, inv_data, df = sf.run(policy="safety_stock")

# %%
print(f"Average costs: {cost} €")
# Out:
# Average costs: 155.11811435852468 €

# %% [markdown]
# # Policy Future Demand
# Order if current stock + incoming orders until next delivery are lower than the safety stock

# %%
cost, inv_data, df = sf.run(policy="future_demand")

# %%
print(f"Average costs: {cost} €")
# Out:
# Average costs: 290.0537140484665 €
